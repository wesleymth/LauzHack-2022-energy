# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
from codecarbon import EmissionsTracker

# %%
! codecarbon init
# Out:
# Welcome to CodeCarbon, here is your experiment id:
# d726f5c0-b436-4a78-9fce-a904b136598c (from ./.codecarbon.config)

# %%
tracker = EmissionsTracker()
X = np.random.randn(10000, 5000)
y = np.random.randn(10000)
tracker.start()
reg = LinearRegression().fit(X, y)
tracker.stop()
# Out:
# [codecarbon INFO @ 18:41:19] [setup] RAM Tracking...
# [codecarbon INFO @ 18:41:19] [setup] GPU Tracking...
# [codecarbon INFO @ 18:41:19] No GPU found.
# [codecarbon INFO @ 18:41:19] [setup] CPU Tracking...
# [codecarbon INFO @ 18:41:19] Tracking Intel CPU via Power Gadget
# [codecarbon INFO @ 18:41:20] >>> Tracker's metadata:
# [codecarbon INFO @ 18:41:20]   Platform system: macOS-10.16-x86_64-i386-64bit
# [codecarbon INFO @ 18:41:20]   Python version: 3.8.8
# [codecarbon INFO @ 18:41:20]   Available RAM : 16.000 GB
# [codecarbon INFO @ 18:41:20]   CPU count: 12
# [codecarbon INFO @ 18:41:20]   CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# [codecarbon INFO @ 18:41:20]   GPU count: None
# [codecarbon INFO @ 18:41:20]   GPU model: None
# [codecarbon INFO @ 18:41:26] Energy consumed for RAM : 0.000000 kWh. RAM Power : 0.47846317291259766 W
# [codecarbon WARNING @ 18:42:13] Background scheduler didn't run for a long period (47s), results might be inaccurate
# [codecarbon WARNING @ 18:42:13] Background scheduler didn't run for a long period (47s), results might be inaccurate
# [codecarbon INFO @ 18:42:13] Energy consumed for RAM : 0.000003 kWh. RAM Power : 0.18684768676757812 W
# [codecarbon INFO @ 18:42:13] Energy consumed for all CPUs : 0.000015 kWh. All CPUs Power : 53.22875 W
# [codecarbon INFO @ 18:42:13] Energy consumed for RAM : 0.000005 kWh. RAM Power : 0.18686342239379883 W
# [codecarbon INFO @ 18:42:14] Energy consumed for all CPUs : 0.000090 kWh. All CPUs Power : 5.601166666666667 W
# [codecarbon INFO @ 18:42:14] 0.000095 kWh of electricity used since the begining.
# [codecarbon INFO @ 18:42:14] Energy consumed for all CPUs : 0.000161 kWh. All CPUs Power : 5.373818181818181 W
# [codecarbon INFO @ 18:42:16] 0.000166 kWh of electricity used since the begining.
# [codecarbon INFO @ 18:42:16] 0.000166 kWh of electricity used since the begining.
# 5.47053973988258e-06

# %%
intel_df = pd.read_csv("intel_power_gadget_log.csv")

# %%
emissions = pd.read_csv("emissions.csv")

# %%
emissions
# Out:
#              timestamp project_name                                run_id  \
# 0  2022-12-03T17:28:09   codecarbon  488e9c98-2c98-443b-b42b-bfeec7d3d296
# 1  2022-12-03T17:29:37   codecarbon  2987465b-a840-4374-87f3-c2f7a05b0a63
# 2  2022-12-03T17:30:09   codecarbon  579892a5-126e-4438-b2d5-6638a0ab7d46
# 3  2022-12-03T17:30:46   codecarbon  d4dd27f9-89b8-4c81-ad81-2b31aac39d73
# 4  2022-12-03T17:46:54   codecarbon  5cd7d754-fb0f-4cd9-a867-6d332bf7de73
# 5  2022-12-03T18:18:01   codecarbon  7d5598f2-efe2-4240-baf1-9f1a17771bf2
# 6  2022-12-03T18:34:29   codecarbon  9118e02c-4b17-4f81-abe3-187a7eddc395
# 7  2022-12-03T18:42:16   codecarbon  cf720ad0-5d61-468c-bb14-67f6570fec91
#
#     duration     emissions  emissions_rate  cpu_power  gpu_power  ram_power  \
# 0   0.006347  1.578293e-09    2.486698e-04  42.500000        0.0   3.000000
# 1   0.003553  5.220559e-10    1.469276e-04  42.500000        0.0   3.000000
# 2   0.005257  1.276538e-09    2.428313e-04  42.500000        0.0   3.000000
# 3   0.021156  6.484003e-09    3.064877e-04  42.500000        0.0   3.000000
# 4   2.925545  5.956083e-08    2.035888e-05   0.000000        0.0   3.000000
# 5   2.863099  1.719002e-09    6.003990e-07   9.557917        0.0   3.000000
# 6  50.166857  1.110191e-05    2.212997e-04   6.307091        0.0   6.000000
# 7  50.751086  5.470540e-06    1.077916e-04   5.373818        0.0   0.186863
#
#      cpu_energy  ...  python_version  cpu_count  \
# 0  4.556941e-08  ...           3.9.7          4
# 1  1.561857e-08  ...           3.9.7          4
# 2  3.795293e-08  ...           3.9.7          4
# 3  1.857566e-07  ...           3.9.7          4
# 4  0.000000e+00  ...           3.9.7          4
# 5  4.051490e-08  ...          3.9.15          4
# 6  1.797986e-04  ...           3.8.8         12
# 7  1.613394e-04  ...           3.8.8         12
#
#                                   cpu_model gpu_count gpu_model longitude  \
# 0  Intel(R) Core(TM) i5-6267U CPU @ 2.90GHz       NaN       NaN     6.607
# 1  Intel(R) Core(TM) i5-6267U CPU @ 2.90GHz       NaN       NaN     6.607
# 2  Intel(R) Core(TM) i5-6267U CPU @ 2.90GHz       NaN       NaN     6.607
# 3  Intel(R) Core(TM) i5-6267U CPU @ 2.90GHz       NaN       NaN     6.607
# 4  Intel(R) Core(TM) i5-6267U CPU @ 2.90GHz       NaN       NaN     6.607
# 5  Intel(R) Core(TM) i5-6267U CPU @ 2.90GHz       NaN       NaN     6.607
# 6  Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz       NaN       NaN     6.607
# 7  Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz       NaN       NaN     6.607
#
#    latitude  ram_total_size tracking_mode on_cloud
# 0    46.488             8.0       machine        N
# 1    46.488             8.0       machine        N
# 2    46.488             8.0       machine        N
# 3    46.488             8.0       machine        N
# 4    46.488             8.0       machine        N
# 5    46.488             8.0       machine        N
# 6    46.488            16.0       machine        N
# 7    46.488            16.0       process        N
#
# [8 rows x 29 columns]

# %%
emissions.iloc[-1]["energy_consumed"]
# Out:
# 0.0001664522053712

# %%
reg = LinearRegression().fit(X, y)

# %% [markdown]
# Model can be linear (ridge, lasso, poly,)  maybe later (randmomforest, xgboost)

# %%
tracker = EmissionsTracker()
df_run_info = pd.DataFrame('n_predictors', 'n_points', 'model')



tracker.start()
LinearRegression.fit(X, y)
tracker.stop()

tracker.start()
Lasso.fit(np.random.rand(rows,columns), y)
tracker.stop()

emissions = pd.read_csv("emissions.csv")



df = pd.DataFrame(columns=['CPU', 'GPU', 'n_predictors', 'n_points', 'model'])
# Out:
# Empty DataFrame
# Columns: [CPU, GPU, n_predictors, n_points, model]
# Index: []

# %%
def linearmodelsrun(model, columns, rows):
    model.fit(np.random.rand(rows,columns), y)
